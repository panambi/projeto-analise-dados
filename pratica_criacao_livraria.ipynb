# %% [markdown]
# <a href="https://colab.research.google.com/github/panambi/projeto-analise-dados/blob/main/pratica_criacao_livraria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/livros.csv')
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# 4         Family saga

# %%
df.shape
# Out:
# (174, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Book                           174 non-null    object
#  1   Author(s)                      174 non-null    object
#  2   Original language              174 non-null    object
#  3   First published                174 non-null    int64
#  4   Approximate sales in millions  174 non-null    float64
#  5   Genre                          118 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.3+ KB

# %%
df['Book']
# Out:
# 0                                   A Tale of Two Cities
# 1                    The Little Prince (Le Petit Prince)
# 2               Harry Potter and the Philosopher's Stone
# 3                               And Then There Were None
# 4                         Dream of the Red Chamber (紅樓夢)
#                              ...
# 169                                             The Goal
# 170                                       Fahrenheit 451
# 171                                       Angela's Ashes
# 172    The Story of My Experiments with Truth (સત્યના...
# 173                                Bridget Jones's Diary
# Name: Book, Length: 174, dtype: object

# %%
df['Approximate sales in millions']
# Out:
# 0      200.0
# 1      200.0
# 2      120.0
# 3      100.0
# 4      100.0
#        ...
# 169     10.0
# 170     10.0
# 171     10.0
# 172     10.0
# 173     10.0
# Name: Approximate sales in millions, Length: 174, dtype: float64

# %%
df.columns
# Out:
# Index(['Book', 'Author(s)', 'Original language', 'First published',
#        'Approximate sales in millions', 'Genre'],
#       dtype='object')

# %%
traducao_colunas = {
    'Book': 'livro',
    'Author(s)': 'autor',
    'Original language': 'idioma_original',
    'First published': 'ano_publicacao',
    'Approximate sales in millions': 'vendas',
    'Genre': 'genero',
       }

# %%
df.rename(columns=traducao_colunas, inplace=True)

# %%
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero
# 0         English            1859   200.0  Historical fiction
# 1          French            1943   200.0             Novella
# 2         English            1997   120.0             Fantasy
# 3         English            1939   100.0             Mystery
# 4         Chinese            1791   100.0         Family saga

# %%
df.isnull().sum()
# Out:
# livro               0
# autor               0
# idioma_original     0
# ano_publicacao      0
# vendas              0
# genero             56
# dtype: int64

# %%
df['autor'].value_counts().head(10)
# Out:
# autor
# J. K. Rowling       7
# Dan Brown           3
# Suzanne Collins     3
# Roald Dahl          3
# George Orwell       2
# Ken Follett         2
# E. L. James         2
# Albert Camus        2
# Erskine Caldwell    2
# Cao Xueqin          1
# Name: count, dtype: int64

# %%
df[df['autor'] == 'J. K. Rowling']
# Out:
#                                         livro          autor idioma_original  \
# 2    Harry Potter and the Philosopher's Stone  J. K. Rowling         English
# 10    Harry Potter and the Chamber of Secrets  J. K. Rowling         English
# 11   Harry Potter and the Prisoner of Azkaban  J. K. Rowling         English
# 12        Harry Potter and the Goblet of Fire  J. K. Rowling         English
# 13  Harry Potter and the Order of the Phoenix  J. K. Rowling         English
# 14     Harry Potter and the Half-Blood Prince  J. K. Rowling         English
# 15       Harry Potter and the Deathly Hallows  J. K. Rowling         English
#
#     ano_publicacao  vendas   genero
# 2             1997   120.0  Fantasy
# 10            1998    77.0  Fantasy
# 11            1999    65.0  Fantasy
# 12            2000    65.0  Fantasy
# 13            2003    65.0  Fantasy
# 14            2005    65.0  Fantasy
# 15            2007    65.0  Fantasy

# %%
autores_unicos = pd.DataFrame(df['autor'].unique(), columns=['autor'])
autores_unicos.head()
# Out:
#                       autor
# 0           Charles Dickens
# 1  Antoine de Saint-Exupéry
# 2             J. K. Rowling
# 3           Agatha Christie
# 4                Cao Xueqin

# %%
autores_unicos.shape
# Out:
# (157, 1)

# %%
autores_unicos['autor_id'] = autores_unicos.index + 1
autores_unicos.head()
# Out:
#                       autor  autor_id
# 0           Charles Dickens         1
# 1  Antoine de Saint-Exupéry         2
# 2             J. K. Rowling         3
# 3           Agatha Christie         4
# 4                Cao Xueqin         5

# %%
df = df.merge(autores_unicos, on='autor', how='left')
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero  autor_id
# 0         English            1859   200.0  Historical fiction         1
# 1          French            1943   200.0             Novella         2
# 2         English            1997   120.0             Fantasy         3
# 3         English            1939   100.0             Mystery         4
# 4         Chinese            1791   100.0         Family saga         5

# %%
df[df['autor'] == 'J. K. Rowling']
# Out:
#                                         livro          autor idioma_original  \
# 2    Harry Potter and the Philosopher's Stone  J. K. Rowling         English
# 10    Harry Potter and the Chamber of Secrets  J. K. Rowling         English
# 11   Harry Potter and the Prisoner of Azkaban  J. K. Rowling         English
# 12        Harry Potter and the Goblet of Fire  J. K. Rowling         English
# 13  Harry Potter and the Order of the Phoenix  J. K. Rowling         English
# 14     Harry Potter and the Half-Blood Prince  J. K. Rowling         English
# 15       Harry Potter and the Deathly Hallows  J. K. Rowling         English
#
#     ano_publicacao  vendas   genero  autor_id
# 2             1997   120.0  Fantasy         3
# 10            1998    77.0  Fantasy         3
# 11            1999    65.0  Fantasy         3
# 12            2000    65.0  Fantasy         3
# 13            2003    65.0  Fantasy         3
# 14            2005    65.0  Fantasy         3
# 15            2007    65.0  Fantasy         3

# %%
df['autor_id'].value_counts()
# Out:
# autor_id
# 3      7
# 10     3
# 54     3
# 55     3
# 51     2
#       ..
# 153    1
# 154    1
# 155    1
# 156    1
# 157    1
# Name: count, Length: 157, dtype: int64

# %%
autores = pd.DataFrame(df['autor'].unique(), columns=['autor'])
autores.head()
# Out:
#                       autor
# 0           Charles Dickens
# 1  Antoine de Saint-Exupéry
# 2             J. K. Rowling
# 3           Agatha Christie
# 4                Cao Xueqin

# %%
from os import replace
with open('autores.sql', 'w', encoding='utf-8') as arquivo:
    for _, row in autores.iterrows():
        nome = row['autor'].replace("'", "''")
        arquivo.write(f"INSERT INTO autores (nome) VALUES ('{nome}');\n")

# %%
df['genero'].isnull().value_counts()
# Out:
# genero
# False    118
# True      56
# Name: count, dtype: int64

# %%
df['genero'] = df['genero'].fillna('unknown')
df.tail(10)
# Out:
#                                                  livro  \
# 164                                     The Joy of Sex
# 165                    The Gospel According to Peanuts
# 166                The Subtle Art of Not Giving a Fuck
# 167                                         Life of Pi
# 168                                   The Front Runner
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                           autor idioma_original  ano_publicacao  vendas  \
# 164                Alex Comfort         English            1972    10.0
# 165             Robert L. Short         English            1965    10.0
# 166                 Mark Manson         English            2016    10.0
# 167                 Yann Martel         English            2001    10.0
# 168        Patricia Nell Warren         English            1974    10.0
# 169         Eliyahu M. Goldratt         English            1984    10.0
# 170                Ray Bradbury         English            1953    10.0
# 171               Frank McCourt         English            1996    10.0
# 172  Mohandas Karamchand Gandhi        Gujarati            1929    10.0
# 173              Helen Fielding         English            1996    10.0
#
#       genero  autor_id
# 164  unknown       148
# 165  unknown       149
# 166  unknown       150
# 167  unknown       151
# 168  unknown       152
# 169  unknown       153
# 170  unknown       154
# 171  unknown       155
# 172  unknown       156
# 173  unknown       157

# %%
df['genero'].value_counts()
# Out:
# genero
# unknown                          56
# Fantasy                          10
# Novel                             8
# Self-help                         7
# Historical fiction                4
#                                  ..
# Autobiographical novel            1
# Historical fiction, war novel     1
# Science fiction                   1
# Dystopian fiction                 1
# Horror                            1
# Name: count, Length: 81, dtype: int64

# %%
df['genero'].isnull().sum()
# Out:
# np.int64(0)

# %%
genero = pd.DataFrame(df['genero'].unique(), columns=['genero'])
genero.head()
# Out:
#                genero
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# 4         Family saga

# %%
# !pip install -q deep-translator

from deep_translator import GoogleTranslator

# Supondo que você tenha um DataFrame chamado generos com a coluna 'genero'
genero['genero_pt'] = genero['genero'].apply(
    lambda x: GoogleTranslator(source='auto', target='pt').translate(x)
)

genero.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  Ficção histórica
# 1             Novella           Novella
# 2             Fantasy          Fantasia
# 3             Mystery          Mistério
# 4         Family saga   Saga da família

# %%
genero['genero_pt'] = genero['genero_pt'].replace('Novella', 'Novela')
genero.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  Ficção histórica
# 1             Novella            Novela
# 2             Fantasy          Fantasia
# 3             Mystery          Mistério
# 4         Family saga   Saga da família

# %%
genero['genero_pt'] = genero['genero_pt'].replace('Saga da família', 'Saga familiar')
genero.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  Ficção histórica
# 1             Novella            Novela
# 2             Fantasy          Fantasia
# 3             Mystery          Mistério
# 4         Family saga     Saga familiar

# %%
genero['genero_pt'] = genero['genero_pt'].str.lower()
genero.head()
# Out:
#                genero         genero_pt
# 0  Historical fiction  ficção histórica
# 1             Novella            novela
# 2             Fantasy          fantasia
# 3             Mystery          mistério
# 4         Family saga     saga familiar

# %%
with open('generos.sql', 'w', encoding='utf-8') as arquivo:
    for nome in genero['genero_pt']:
      nome_validado = nome.replace("'", "''")
      arquivo.write(f"INSERT INTO generos (nome) VALUES ('{nome_validado}');\n")

# %%
df.columns
# Out:
# Index(['livro', 'autor', 'idioma_original', 'ano_publicacao', 'vendas',
#        'genero', 'autor_id'],
#       dtype='object')

# %%
genero['genero_id'] = genero.index + 1
genero.head()
# Out:
#                genero         genero_pt  genero_id
# 0  Historical fiction  ficção histórica          1
# 1             Novella            novela          2
# 2             Fantasy          fantasia          3
# 3             Mystery          mistério          4
# 4         Family saga     saga familiar          5

# %%
df = df.merge(genero[['genero', 'genero_id']], on='genero', how='left')
df.head()
# Out:
#                                       livro                     autor  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   idioma_original  ano_publicacao  vendas              genero  autor_id  \
# 0         English            1859   200.0  Historical fiction         1
# 1          French            1943   200.0             Novella         2
# 2         English            1997   120.0             Fantasy         3
# 3         English            1939   100.0             Mystery         4
# 4         Chinese            1791   100.0         Family saga         5
#
#    genero_id
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
with open('livros.sql', 'w', encoding='utf-8') as f:
    for _, row in df.iterrows():
        nome_livro = row['livro'].replace("'", "''")  # Escapa aspas simples
        idioma = row['idioma_original'].replace("'", "''")
        ano = int(row['ano_publicacao'])
        vendas = float(row['vendas'])
        autor_id = int(row['autor_id'])
        genero_id = int(row['genero_id'])

        sql = (
            f"INSERT INTO livros (nome, idioma, ano_publicacao, vendas, autor_id, genero_id) "
            f"VALUES ('{nome_livro}', '{idioma}', {ano}, {vendas:.2f}, {autor_id}, {genero_id});\n"
        )
        f.write(sql)
