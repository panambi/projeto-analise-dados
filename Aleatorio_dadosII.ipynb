# %% [markdown]
# <a href="https://colab.research.google.com/github/panambi/projeto-analise-dados/blob/main/Aleatorio_dadosII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importação de bibliotecas
import random
import matplotlib.pyplot as plt

# Gerar uma lista com 10 números aleatorios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

#Exibir a lista gerada
print("Lista de números aleatórios:", dados)

# Plotar os dados
plt.plot(dados, marker='o')   # marcador em cada dados para melhor visualização
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.title('Gráfico de Dados Aleatórios')
plt.grid(True)
plt.show()
# Out:
# Lista de números aleatórios: [77, 88, 2, 83, 80, 90, 61, 54, 28, 42]
